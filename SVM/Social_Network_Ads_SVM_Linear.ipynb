# %%
# !git clone https://github.com/s7s/machine_learning_1.git
# %cd  machine_learning_1/support_vector_machines
# Out:
# Cloning into 'machine_learning_1'...
# remote: Enumerating objects: 378, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 378 (delta 74), reused 3 (delta 1), pack-reused 252 (from 1)
# Receiving objects: 100% (378/378), 42.71 MiB | 21.84 MiB/s, done.
# Resolving deltas: 100% (197/197), done.
# /content/machine_learning_1/support_vector_machines/machine_learning_1/support_vector_machines

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import utils

# %%
Data = pd.read_csv('Social_Network_Ads (2).csv')
Data
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X = Data[['Age' , 'EstimatedSalary']]
Y = Data['Purchased']
utils.plot_points(X,Y)

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X , Y , test_size = 0.25 , random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
S = StandardScaler()
x_train_scaled = S.fit_transform(x_train)
x_test_scaled = S.transform(x_test)

# %%
print(x_train_scaled)
# Out:
# [[ 0.58164944 -0.88670699]
#  [-0.60673761  1.46173768]
#  [-0.01254409 -0.5677824 ]
#  [-0.60673761  1.89663484]
#  [ 1.37390747 -1.40858358]
#  [ 1.47293972  0.99784738]
#  [ 0.08648817 -0.79972756]
#  [-0.01254409 -0.24885782]
#  [-0.21060859 -0.5677824 ]
#  [-0.21060859 -0.19087153]
#  [-0.30964085 -1.29261101]
#  [-0.30964085 -0.5677824 ]
#  [ 0.38358493  0.09905991]
#  [ 0.8787462  -0.59677555]
#  [ 2.06713324 -1.17663843]
#  [ 1.07681071 -0.13288524]
#  [ 0.68068169  1.78066227]
#  [-0.70576986  0.56295021]
#  [ 0.77971394  0.35999821]
#  [ 0.8787462  -0.53878926]
#  [-1.20093113 -1.58254245]
#  [ 2.1661655   0.93986109]
#  [-0.01254409  1.22979253]
#  [ 0.18552042  1.08482681]
#  [ 0.38358493 -0.48080297]
#  [-0.30964085 -0.30684411]
#  [ 0.97777845 -0.8287207 ]
#  [ 0.97777845  1.8676417 ]
#  [-0.01254409  1.25878567]
#  [-0.90383437  2.27354572]
#  [-1.20093113 -1.58254245]
#  [ 2.1661655  -0.79972756]
#  [-1.39899564 -1.46656987]
#  [ 0.38358493  2.30253886]
# ...

# %%
print(x_test_scaled)
# Out:
# [[-0.80480212  0.50496393]
#  [-0.01254409 -0.5677824 ]
#  [-0.30964085  0.1570462 ]
#  [-0.80480212  0.27301877]
#  [-0.30964085 -0.5677824 ]
#  [-1.10189888 -1.43757673]
#  [-0.70576986 -1.58254245]
#  [-0.21060859  2.15757314]
#  [-1.99318916 -0.04590581]
#  [ 0.8787462  -0.77073441]
#  [-0.80480212 -0.59677555]
#  [-1.00286662 -0.42281668]
#  [-0.11157634 -0.42281668]
#  [ 0.08648817  0.21503249]
#  [-1.79512465  0.47597078]
#  [-0.60673761  1.37475825]
#  [-0.11157634  0.21503249]
#  [-1.89415691  0.44697764]
#  [ 1.67100423  1.75166912]
#  [-0.30964085 -1.37959044]
#  [-0.30964085 -0.65476184]
#  [ 0.8787462   2.15757314]
#  [ 0.28455268 -0.53878926]
#  [ 0.8787462   1.02684052]
#  [-1.49802789 -1.20563157]
#  [ 1.07681071  2.07059371]
#  [-1.00286662  0.50496393]
#  [-0.90383437  0.30201192]
#  [-0.11157634 -0.21986468]
#  [-0.60673761  0.47597078]
#  [-1.6960924   0.53395707]
#  [-0.11157634  0.27301877]
#  [ 1.86906873 -0.27785096]
#  [-0.11157634 -0.48080297]
# ...

# %%
x_test
# Out:
#      Age  EstimatedSalary
# 132   30            87000
# 309   38            50000
# 341   35            75000
# 196   30            79000
# 246   35            50000
# ..   ...              ...
# 146   27            96000
# 135   23            63000
# 390   48            33000
# 264   48            90000
# 364   42           104000
#
# [100 rows x 2 columns]

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear')
model.fit(x_train_scaled , y_train)
# Out:
# SVC(kernel='linear')

# %%
print(model.predict(S.transform([[30 , 87000]])))
# Out:
# [0]

# %%
print(model.score(x_test_scaled , y_test))
# Out:
# 0.9

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_decision_boundary(X, y, model):
    if isinstance(X, pd.DataFrame):
        X = X.values
    if isinstance(y, pd.Series):
        y = y.values

    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01),
                         np.arange(y_min, y_max, 0.01))

    grid = np.c_[xx.ravel(), yy.ravel()]
    Z = model.predict(grid)
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.coolwarm)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.coolwarm, edgecolors='k')
    plt.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1],
                s=100, facecolors='none', edgecolors='k', linewidths=1.5, label='Support Vectors')
    plt.title('SVM Decision Boundary (Linear Kernel) fot training...')
    plt.legend()
    plt.show()

plot_decision_boundary(x_train_scaled, y_train, model)

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay

y_prediction = model.predict(x_test_scaled)
cm = confusion_matrix(y_test , y_prediction)

display = ConfusionMatrixDisplay(confusion_matrix = cm , display_labels = model.classes_)
display.plot()

# %%
from sklearn.metrics import f1_score,recall_score,precision_score

print(f1_score(y_test , y_prediction))
print(recall_score(y_test , y_prediction))
print(precision_score(y_test , y_prediction))
# Out:
# 0.8275862068965517
# 0.75
# 0.9230769230769231

# %%
#C Value	Precision	Recall	F1-Score
#C = 100	92.0%	71.9%	80.7%
#C = 1	92.3%	75.0%	82.8%
#C = 0.01	95.2%	62.5%	75.5%

# %%
# polynomial kernal for circular dataset
Poly_Data = pd.read_csv('/content/drive/MyDrive/Datasets/one_circle.csv')
Poly_Data
# Out:
#      Unnamed: 0       x_1       x_2  y
# 0             0 -0.759416  2.753240  0
# 1             1 -1.885278  1.629527  0
# 2             2  2.463302 -1.023869  0
# 3             3 -1.986004 -0.898810  0
# 4             4  2.010834 -2.580117  0
# ..          ...       ...       ... ..
# 105         105 -1.376637  2.778703  1
# 106         106 -0.703722  0.215382  1
# 107         107  0.729767 -2.479655  1
# 108         108 -1.715920 -0.393404  1
# 109         109  2.382873 -2.951074  0
#
# [110 rows x 4 columns]

# %%
features = Poly_Data[['x_1' , 'x_2']]
label = Poly_Data['y']
utils.plot_points(features , label)

# %%
poly_model_degree2 = SVC(kernel='poly' , degree = 2)
poly_model_degree2.fit(features , label)
print("Polynomial kernel of degree = 2")
print(f"Accuracy = {poly_model_degree2.score(features , label)}")
utils.plot_model(features , label , poly_model_degree2)
# Out:
# Polynomial kernel of degree = 2
# Accuracy = 0.8909090909090909

# %%
poly_model = SVC(kernel='poly' , degree = 4)
poly_model.fit(features , label)
print("Polynomial kernel of degree = 4")
print(f"Accuracy = {poly_model.score(features , label)}")
utils.plot_model(features , label , poly_model)
# Out:
# Polynomial kernel of degree = 4
# Accuracy = 0.9

# %%
#Experimenting with gammas in the rbf kernel
rbf_data = pd.read_csv('/content/drive/MyDrive/Datasets/two_circles.csv')
rbf_data
# Out:
#      Unnamed: 0       x_1       x_2  y
# 0             0  0.271606 -1.119853  1
# 1             1  1.681520  0.120557  1
# 2             2 -1.509630  2.542006  0
# 3             3 -0.631786  0.538599  1
# 4             4 -0.684341 -0.730527  1
# ..          ...       ...       ... ..
# 215         215 -1.510864  0.878528  1
# 216         216 -0.771865 -1.026592  1
# 217         217 -0.632831  1.886546  1
# 218         218 -2.212179  1.209690  1
# 219         219 -2.289239  0.815806  1
#
# [220 rows x 4 columns]

# %%
feature = rbf_data[['x_1' , 'x_2']]
labels = rbf_data['y']
utils.plot_points(feature , labels)

# %%
rbf_model = SVC(kernel = 'rbf' , gamma=1)
rbf_model.fit(feature , labels)
print(f"Accuracy = {rbf_model.score(feature , labels)}")
utils.plot_model(feature , labels , rbf_model)
# Out:
# Accuracy = 0.9045454545454545

# %%
rbf_model = SVC(kernel = 'rbf' , gamma=100)
rbf_model.fit(feature , labels)
print(f"Accuracy = {rbf_model.score(feature , labels)}")
utils.plot_model(feature , labels , rbf_model)
# Out:
# Accuracy = 0.990909090909091

# %%
rbf_model = SVC(kernel = 'rbf' , gamma=10)
rbf_model.fit(feature , labels)
print(f"Accuracy = {rbf_model.score(feature , labels)}")
utils.plot_model(feature , labels , rbf_model)
# Out:
# Accuracy = 0.9636363636363636
